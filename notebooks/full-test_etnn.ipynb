# %% [markdown]
# # Full test ETNN configs determined by optuna

# %% [markdown]
# ## Importing section

# %%
import os
import sys
sys.path.insert(0, os.path.pardir)

# %%
import pandas as pd

from etnn.routines.run_config import run_config

import matplotlib.pyplot as plt

from etnn.tools.training_tools import ConfigStore

# %% [markdown]
# ## Definitions section

# %%
def create_plot(
        config_idx: int,
        what: str = "r2"
) -> None:
    plt.figure()
    # load data
    STORAGE_FOLDER = os.path.join("../results", str(config_idx))
    df_measures = pd.read_csv(os.path.join(STORAGE_FOLDER, "accuracies.csv"))

    # Plot the initial data
    for config_id in df_measures.config_id.unique():
        # make subdataset for config id
        sub_df = df_measures[df_measures.config_id == config_id]

        # plot train test and val
        for mode in ['train', 'test', 'val']:
            # plot training
            plt.plot(sub_df.epoch, sub_df[f"{mode}_{what}"], label=f"{config_id}_{mode}-{what}")

    plt.title(f"{what} plot")
    plt.xlabel("epoch")
    plt.ylabel("score")
    if what == "r2":
        plt.ylim(-1, +1)
    plt.legend()
    plt.show()

# %% [markdown]
# ## Tree advanced label

# %%
# define label to show
label = "tree_advanced"

# load config storage
config_table = pd.read_csv("study_label-tree-advanced.csv")

# sort config storage
config_table = config_table.sort_values(by=['value'], ascending=False)

# iterate over top 3 best configs
for i in range(3):
    # get entry from dataframe
    entry = config_table.iloc[i]

    # print information to console
    print(f"Rank {i+1} parameter configuration: {entry}")

    # setup config
    config = ConfigStore(
        in_dim=15,
        hidden_dim=int(entry.params_hidden_dim),
        out_dim=1,
        k=int(entry.params_k),
        dataset=0,
        ds_size=10_000,
        num_gondolas=10,
        num_part_pg=5,
        loss_name='mse',
        optimizer_name='adam',
        num_max_epochs=300,
        learning_rate=float(entry.params_learning_rate),
        batch_size=1024,
        early_stop_tol=5,
        use_equal_batcher=bool(entry.params_batcher),
        seed=420,
        label_type=label,
        final_label_factor=1/1000
    )

    # run config and retrieve idx
    config_idx = run_config(
        config=config,
        dataset_path="../datasets",
        verbose=True,
        results_folder="../results",
        check_duplicate=True
    )

    # plot results
    create_plot(config_idx, what="r2")
    create_plot(config_idx, what="loss")
# Out:
# Rank 1 parameter configuration: Unnamed: 0                                      34
# number                                          34
# value                                     0.998455
# datetime_start          2023-12-06 15:11:08.668067
# datetime_complete       2023-12-06 15:12:50.482356
# duration                    0 days 00:01:41.814289
# params_batcher                               False
# params_hidden_dim                               16
# params_k                                         2
# params_learning_rate                       0.00278
# state                                     COMPLETE
# Name: 34, dtype: object
# 100%|██████████| 300/300 [20:33<00:00,  4.11s/it]
# 100%|██████████| 300/300 [17:19<00:00,  3.47s/it]
# Rank 2 parameter configuration: Unnamed: 0                                      55
# number                                          55
# value                                     0.998418
# datetime_start          2023-12-06 15:49:12.323436
# datetime_complete       2023-12-06 15:51:00.335377
# duration                    0 days 00:01:48.011941
# params_batcher                               False
# params_hidden_dim                               16
# params_k                                         2
# params_learning_rate                      0.002741
# state                                     COMPLETE
# Name: 55, dtype: object
# 100%|██████████| 300/300 [21:30<00:00,  4.30s/it]
# 100%|██████████| 300/300 [17:51<00:00,  3.57s/it]
# Rank 3 parameter configuration: Unnamed: 0                                      93
# number                                          93
# value                                     0.997795
# datetime_start          2023-12-06 16:57:31.721904
# datetime_complete       2023-12-06 16:59:28.908790
# duration                    0 days 00:01:57.186886
# params_batcher                               False
# params_hidden_dim                               48
# params_k                                         1
# params_learning_rate                      0.000921
# state                                     COMPLETE
# Name: 93, dtype: object
# 100%|██████████| 300/300 [22:41<00:00,  4.54s/it]
# 100%|██████████| 300/300 [19:09<00:00,  3.83s/it]

# %% [markdown]
# ## Tree label

# %%
# define label to show
label = "tree"

# load config storage
config_table = pd.read_csv("study_label-tree.csv")

# sort config storage
config_table = config_table.sort_values(by=['value'], ascending=False)

# iterate over top 3 best configs
for i in range(3):
    # get entry from dataframe
    entry = config_table.iloc[i]

    # print information to console
    print(f"Rank {i+1} parameter configuration: {entry}")

    # setup config
    config = ConfigStore(
        in_dim=15,
        hidden_dim=int(entry.params_hidden_dim),
        out_dim=1,
        k=int(entry.params_k),
        dataset=0,
        ds_size=10_000,
        num_gondolas=10,
        num_part_pg=5,
        loss_name='mse',
        optimizer_name='adam',
        num_max_epochs=300,
        learning_rate=float(entry.params_learning_rate),
        batch_size=1024,
        early_stop_tol=5,
        use_equal_batcher=bool(entry.params_batcher),
        seed=420,
        label_type=label,
        final_label_factor=1/1000
    )

    # run config and retrieve idx
    config_idx = run_config(
        config=config,
        dataset_path="../datasets",
        verbose=True,
        results_folder="../results",
        check_duplicate=True
    )

    # plot results
    create_plot(config_idx, what="r2")
    create_plot(config_idx, what="loss")
# Out:
# Rank 1 parameter configuration: Unnamed: 0                                      32
# number                                          32
# value                                     0.866971
# datetime_start          2023-12-06 21:15:37.084800
# datetime_complete       2023-12-06 21:17:11.545920
# duration                    0 days 00:01:34.461120
# params_batcher                                True
# params_hidden_dim                               64
# params_k                                         1
# params_learning_rate                      0.000056
# state                                     COMPLETE
# Name: 32, dtype: object
#   0%|          | 0/300 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 41
#      19 config = ConfigStore(
#      20     in_dim=15,
#      21     hidden_dim=entry.params_hidden_dim,
#    (...)
#      37     final_label_factor=1/1000
#      38 )
#      40 # run config and retrieve idx
# ---> 41 config_idx = run_config(
#      42     config=config,
#      43     dataset_path="../datasets",
#      44     verbose=True,
#      45     results_folder="../results",
#      46     check_duplicate=True
#      47 )
#      49 # plot results
#      50 create_plot(config_idx, what="r2")
#
# File D:\DATEN\P2_EquivariantTreeNN\notebooks\..\etnn\routines\run_config.py:167, in run_config(config, dataset_path, results_folder, check_duplicate, verbose)
#     151     accuracy_protocoller.calc_and_collect(
#     152         config_id="etnn",
#     153         epoch=epoch + 1,
#    (...)
#     162         #    test_loss=test_mean_loss,
#     163     )
#     165     # check if model is better and save it
#     166     # todo: probably not required to write config over and over again
# --> 167     if epoch_control.retain_best(model, train_mean_loss, val_mean_loss, config):
#     168         break
#     170 # REPEAT FOR BASELINE MODEL
#
# File D:\DATEN\P2_EquivariantTreeNN\notebooks\..\etnn\tools\training_tools.py:218, in EpochControl.retain_best(self, model, train_value, eval_value, config)
#     216     torch.save(model.state_dict(), self.model_save_path)
#     217     if config is not None:
# --> 218         config_to_json(config, self.config_save_path)
#     219 return
#
# File D:\DATEN\P2_EquivariantTreeNN\notebooks\..\etnn\tools\training_tools.py:84, in config_to_json(config, saving_path)
#      79 def config_to_json(
#      80         config: ConfigStore,
#      81         saving_path: str
#      82 ):
#      83     with open(saving_path, 'w') as file:
# ---> 84         json.dump(vars(config), file, indent=4)
#      85     return
#
# File ~\anaconda3\envs\P2\lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~\anaconda3\envs\P2\lib\json\encoder.py:431, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     429     yield from _iterencode_list(o, _current_indent_level)
#     430 elif isinstance(o, dict):
# --> 431     yield from _iterencode_dict(o, _current_indent_level)
#     432 else:
#     433     if markers is not None:
#
# File ~\anaconda3\envs\P2\lib\json\encoder.py:405, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     403         else:
#     404             chunks = _iterencode(value, _current_indent_level)
# --> 405         yield from chunks
#     406 if newline_indent is not None:
#     407     _current_indent_level -= 1
#
# File ~\anaconda3\envs\P2\lib\json\encoder.py:438, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     436         raise ValueError("Circular reference detected")
#     437     markers[markerid] = o
# --> 438 o = _default(o)
#     439 yield from _iterencode(o, _current_indent_level)
#     440 if markers is not None:
#
# File ~\anaconda3\envs\P2\lib\json\encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type int64 is not JSON serializable

# %% [markdown]
# ## Default label

# %%
# define label to show
label = "default"

# load config storage
config_table = pd.read_csv("study_label-default.csv")

# sort config storage
config_table = config_table.sort_values(by=['value'], ascending=False)

# iterate over top 3 best configs
for i in range(3):
    # get entry from dataframe
    entry = config_table.iloc[i]

    # print information to console
    print(f"Rank {i+1} parameter configuration: {entry}")

    # setup config
    config = ConfigStore(
        in_dim=15,
        hidden_dim=entry.params_hidden_dim,
        out_dim=1,
        k=entry.params_k,
        dataset=0,
        ds_size=10_000,
        num_gondolas=10,
        num_part_pg=5,
        loss_name='mse',
        optimizer_name='adam',
        num_max_epochs=300,
        learning_rate=entry.params_learning_rate,
        batch_size=1024,
        early_stop_tol=5,
        use_equal_batcher=entry.params_batcher,
        seed=420,
        label_type=label,
        final_label_factor=1/1000
    )

    # run config and retrieve idx
    config_idx = run_config(
        config=config,
        dataset_path="../datasets",
        verbose=True,
        results_folder="../results",
        check_duplicate=True
    )

    # plot results
    create_plot(config_idx, what="r2")
    create_plot(config_idx, what="loss")
