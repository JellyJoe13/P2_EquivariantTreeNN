# %% [markdown]
# # Full test ETNN configs determined by optuna

# %% [markdown]
# ## Importing section

# %%
import os
import sys

from etnn.tools.param_calc_config import calc_n_params_config

sys.path.insert(0, os.path.pardir)

# %%
import pandas as pd

from etnn.routines.run_config import run_config

import matplotlib.pyplot as plt

from etnn.tools.training_tools import ConfigStore

# %% [markdown]
# ## Definitions section

# %%
def create_plot(
        config_idx: int,
        what: str = "r2"
) -> None:
    plt.figure()
    # load data
    STORAGE_FOLDER = os.path.join("../../results", str(config_idx))
    df_measures = pd.read_csv(os.path.join(STORAGE_FOLDER, "accuracies.csv"))

    # Plot the initial data
    for config_id in df_measures.config_id.unique():
        # make subdataset for config id
        sub_df = df_measures[df_measures.config_id == config_id]

        # plot train test and val
        for mode in ['train', 'test', 'val']:
            # plot training
            if f"{mode}_{what}" in sub_df.columns:
                plt.plot(sub_df.epoch, sub_df[f"{mode}_{what}"], label=f"{config_id}_{mode}-{what}")

    plt.title(f"{what} plot")
    plt.xlabel("epoch")
    plt.ylabel("score")
    if what == "r2":
        plt.ylim(-1, +1)
    plt.legend()
    plt.show()

# %% [markdown]
# ## Tree advanced label

# %%
# define label to show
label = "tree_advanced"

# load config storage
config_table = pd.read_csv("study_label-tree-advanced_normalized.csv")

# sort config storage
config_table = config_table.sort_values(by=['value'], ascending=False)

# iterate over top 3 best configs
for i in range(3):
    # get entry from dataframe
    entry = config_table.iloc[i]

    # print information to console
    print(f"Rank {i+1} parameter configuration: {entry}")

    # setup config
    config = ConfigStore(
        in_dim=15,
        hidden_dim=int(entry.params_hidden_dim),
        out_dim=1,
        k=int(entry.params_k),
        dataset=-1,
        ds_size=10_000,
        num_gondolas=10,
        num_part_pg=5,
        loss_name='mse',
        optimizer_name='adam',
        num_max_epochs=300,
        learning_rate=float(entry.params_learning_rate),
        batch_size=1024,
        early_stop_tol=5,
        use_equal_batcher=bool(entry.params_batcher),
        seed=420,
        label_type=label,
        final_label_factor=1/1000
    )

    # run config and retrieve idx
    config_idx = run_config(
        config=config,
        dataset_path="../../datasets",
        verbose=True,
        results_folder="../../results",
        check_duplicate=True
    )

    # print number of parameters
    n_params_etnn, n_params_baseline = calc_n_params_config(config)
    print(f"Parameters etnn: {n_params_etnn}\nParameters baseline: {n_params_baseline}")

    # plot results
    create_plot(config_idx, what="r2")
    create_plot(config_idx, what="loss")
# Out:
# Rank 1 parameter configuration: Unnamed: 0                                      42
# number                                          42
# value                                     0.962497
# datetime_start          2023-12-08 17:08:16.425677
# datetime_complete       2023-12-08 17:09:34.385643
# duration                    0 days 00:01:17.959966
# params_batcher                                True
# params_hidden_dim                              176
# params_k                                         3
# params_learning_rate                      0.005817
# state                                     COMPLETE
# Name: 42, dtype: object
# Parameters etnn: 209265
# Parameters baseline: 218628
# Rank 2 parameter configuration: Unnamed: 0                                       9
# number                                           9
# value                                     0.959574
# datetime_start          2023-12-08 16:24:17.675080
# datetime_complete       2023-12-08 16:25:35.402398
# duration                    0 days 00:01:17.727318
# params_batcher                                True
# params_hidden_dim                              448
# params_k                                         3
# params_learning_rate                      0.000661
# state                                     COMPLETE
# Name: 9, dtype: object
# Parameters etnn: 1339969
# Parameters baseline: 1405281
# Rank 3 parameter configuration: Unnamed: 0                                      16
# number                                          16
# value                                     0.953689
# datetime_start          2023-12-08 16:33:53.446611
# datetime_complete       2023-12-08 16:35:11.655403
# duration                    0 days 00:01:18.208792
# params_batcher                                True
# params_hidden_dim                              336
# params_k                                         5
# params_learning_rate                      0.002964
# state                                     COMPLETE
# Name: 16, dtype: object
# Parameters etnn: 982129
# Parameters baseline: 1031043

# %% [markdown]
# ## Tree label

# %%
# define label to show
label = "tree"

# load config storage
config_table = pd.read_csv("study_label-tree_normalized.csv")

# sort config storage
config_table = config_table.sort_values(by=['value'], ascending=False)

# iterate over top 3 best configs
for i in range(3):
    # get entry from dataframe
    entry = config_table.iloc[i]

    # print information to console
    print(f"Rank {i+1} parameter configuration: {entry}")

    # setup config
    config = ConfigStore(
        in_dim=15,
        hidden_dim=int(entry.params_hidden_dim),
        out_dim=1,
        k=int(entry.params_k),
        dataset=-1,
        ds_size=10_000,
        num_gondolas=10,
        num_part_pg=5,
        loss_name='mse',
        optimizer_name='adam',
        num_max_epochs=300,
        learning_rate=float(entry.params_learning_rate),
        batch_size=1024,
        early_stop_tol=5,
        use_equal_batcher=bool(entry.params_batcher),
        seed=420,
        label_type=label,
        final_label_factor=1/1000
    )

    # run config and retrieve idx
    config_idx = run_config(
        config=config,
        dataset_path="../../datasets",
        verbose=True,
        results_folder="../../results",
        check_duplicate=True
    )

    # print number of parameters
    n_params_etnn, n_params_baseline = calc_n_params_config(config)
    print(f"Parameters etnn: {n_params_etnn}\nParameters baseline: {n_params_baseline}")

    # plot results
    create_plot(config_idx, what="r2")
    create_plot(config_idx, what="loss")
# Out:
# Rank 1 parameter configuration: Unnamed: 0                                      40
# number                                          40
# value                                     0.829168
# datetime_start          2023-12-08 18:10:01.978360
# datetime_complete       2023-12-08 18:11:22.405479
# duration                    0 days 00:01:20.427119
# params_batcher                                True
# params_hidden_dim                              384
# params_k                                         4
# params_learning_rate                       0.00278
# state                                     COMPLETE
# Name: 40, dtype: object
# Parameters etnn: 1133569
# Parameters baseline: 1187522
# Rank 2 parameter configuration: Unnamed: 0                                      24
# number                                          24
# value                                     0.817257
# datetime_start          2023-12-08 17:48:53.625458
# datetime_complete       2023-12-08 17:50:11.996745
# duration                    0 days 00:01:18.371287
# params_batcher                                True
# params_hidden_dim                              224
# params_k                                         5
# params_learning_rate                      0.004247
# state                                     COMPLETE
# Name: 24, dtype: object
# Parameters etnn: 438369
# Parameters baseline: 457299
# Rank 3 parameter configuration: Unnamed: 0                                      16
# number                                          16
# value                                     0.807169
# datetime_start          2023-12-08 17:38:18.965440
# datetime_complete       2023-12-08 17:39:39.074704
# duration                    0 days 00:01:20.109264
# params_batcher                                True
# params_hidden_dim                              416
# params_k                                         5
# params_learning_rate                      0.002082
# state                                     COMPLETE
# Name: 16, dtype: object
# Parameters etnn: 1503009
# Parameters baseline: 1574189

# %% [markdown]
# ## Default label

# %%
# define label to show
label = "default"

# load config storage
config_table = pd.read_csv("study_label-default_normalized.csv")

# sort config storage
config_table = config_table.sort_values(by=['value'], ascending=False)

# iterate over top 3 best configs
for i in range(3):
    # get entry from dataframe
    entry = config_table.iloc[i]

    # print information to console
    print(f"Rank {i+1} parameter configuration: {entry}")

    # setup config
    config = ConfigStore(
        in_dim=15,
        hidden_dim=int(entry.params_hidden_dim),
        out_dim=1,
        k=int(entry.params_k),
        dataset=-1,
        ds_size=10_000,
        num_gondolas=10,
        num_part_pg=5,
        loss_name='mse',
        optimizer_name='adam',
        num_max_epochs=300,
        learning_rate=float(entry.params_learning_rate),
        batch_size=1024,
        early_stop_tol=5,
        use_equal_batcher=bool(entry.params_batcher),
        seed=420,
        label_type=label,
        final_label_factor=1/1000
    )

    # run config and retrieve idx
    config_idx = run_config(
        config=config,
        dataset_path="../../datasets",
        verbose=True,
        results_folder="../../results",
        check_duplicate=True
    )

    # print number of parameters
    n_params_etnn, n_params_baseline = calc_n_params_config(config)
    print(f"Parameters etnn: {n_params_etnn}\nParameters baseline: {n_params_baseline}")

    # plot results
    create_plot(config_idx, what="r2")
    create_plot(config_idx, what="loss")
# Out:
# Rank 1 parameter configuration: Unnamed: 0                                      33
# number                                          33
# value                                    -0.064534
# datetime_start          2023-12-08 19:13:37.521207
# datetime_complete       2023-12-08 19:15:04.821676
# duration                    0 days 00:01:27.300469
# params_batcher                               False
# params_hidden_dim                              288
# params_k                                         4
# params_learning_rate                      0.002537
# state                                     COMPLETE
# Name: 33, dtype: object
# Parameters etnn: 639361
# Parameters baseline: 669299
# Rank 2 parameter configuration: Unnamed: 0                                      34
# number                                          34
# value                                    -0.069729
# datetime_start          2023-12-08 19:15:04.823681
# datetime_complete       2023-12-08 19:16:28.874782
# duration                    0 days 00:01:24.051101
# params_batcher                               False
# params_hidden_dim                              320
# params_k                                         3
# params_learning_rate                       0.00238
# state                                     COMPLETE
# Name: 34, dtype: object
# Parameters etnn: 685761
# Parameters baseline: 717019
# Rank 3 parameter configuration: Unnamed: 0                                      43
# number                                          43
# value                                    -0.074655
# datetime_start          2023-12-08 19:28:13.634361
# datetime_complete       2023-12-08 19:29:41.771979
# duration                    0 days 00:01:28.137618
# params_batcher                               False
# params_hidden_dim                              256
# params_k                                         5
# params_learning_rate                      0.004105
# state                                     COMPLETE
# Name: 43, dtype: object
# Parameters etnn: 571649
# Parameters baseline: 600671
